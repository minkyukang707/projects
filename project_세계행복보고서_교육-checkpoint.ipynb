# %%
import pandas as pd 
import geopandas as gpd 
import matplotlib.colors
import pycountry
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

background_color = "#fafafa"
#colors
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"

# %%
df= pd.read_csv('C:/py/2019.csv')
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
#        'birth', 'obesity', 'continent'],
#       dtype='object')

# %%
#kmeans
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=4)
kmeans.fit(df[['schooling']])
df['kmeans']= kmeans.labels_

# %%
df.sort_values(by='schooling',ascending=False).head()
# Out:
#            country  year     HS  log_gdp  social  life_exp  freedom  \
# 42         Germany  2019  7.035   10.893   0.886      72.5    0.885
# 132  United States  2019  6.944   11.043   0.917      68.2    0.836
# 119    Switzerland  2019  7.694   11.136   0.949      74.4    0.913
# 21          Canada  2019  7.109   10.800   0.925      73.8    0.912
# 54          Israel  2019  7.332   10.601   0.946      73.5    0.834
#
#      generosity  corruption  mental  schooling  alcohol  suicide  birth  \
# 42        0.057       0.462   6.539       14.1    4.634    1.289  1.600
# 132       0.144       0.707   7.142       13.4    3.242    1.708  1.772
# 119       0.036       0.294   8.112       13.4    1.766    1.755  1.542
# 21        0.112       0.436   7.438       13.3    2.318    1.652  1.509
# 54        0.085       0.743   8.361       13.0    0.592    1.187  3.018
#
#      obesity continent  kmeans
# 42     10.88        EU       2
# 132    14.31     Nor.A       2
# 119     8.82        EU       2
# 21     11.75     Nor.A       2
# 54     10.03        AS       2

# %%
df.sort_values(by='schooling',ascending=False).tail()
# Out:
#          country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 46        Guinea  2019  4.768    7.849   0.655      55.5    0.691       0.097
# 75          Mali  2019  4.988    7.752   0.755      52.2    0.670      -0.038
# 22          Chad  2019  4.251    7.365   0.640      48.7    0.537       0.055
# 91         Niger  2019  5.004    7.106   0.677      54.0    0.831       0.026
# 18  Burkina Faso  2019  4.741    7.691   0.683      54.4    0.678      -0.004
#
#     corruption  mental  schooling  alcohol  suicide  birth  obesity continent  \
# 46       0.756   2.111        2.6    1.969    0.689  4.625     3.14        AF
# 75       0.670   1.610        2.3    1.275    0.390  5.785     1.95        AF
# 22       0.832   1.660        2.3    1.764    0.540  5.649     1.39        AF
# 91       0.729   1.872        2.0    1.457    0.437  6.824     1.48        AF
# 18       0.729   2.022        1.5    2.684    0.826  5.109     2.57        AF
#
#     kmeans
# 46       0
# 75       0
# 22       0
# 91       0
# 18       0

# %%
geo_temp=df

def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
geo_temp['CODE']=alpha3code(geo_temp['country'])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']
merge=pd.merge(world,geo_temp,on='CODE')

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['red','green','blue'])
ax = world.plot(figsize=(20,15), linewidth=0.25, edgecolor=background_color, color='lightgray')
ax.axis('off')
ax.set_facecolor(background_color)
merge.plot(column='kmeans',figsize=(20, 15),legend=False,cmap=cmap,ax=ax)


ax.text(-175,112,'Distribution of schooling 2019',fontsize=30,fontweight='bold',color='#323232')
plt.show()
