# %%
import pandas as pd 
import geopandas as gpd 
import matplotlib.colors
import pycountry
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

background_color = "#fafafa"
#colors
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"

# %%
df= pd.read_csv('C:/py/2019.csv')
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
#        'birth', 'obesity', 'continent'],
#       dtype='object')

# %%
#kmeans
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=4)
kmeans.fit(df[['HS']])
df['kmeans']= kmeans.labels_

# %%
df.sort_values(by='HS',ascending=False).head()
# Out:
#          country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 37       Finland  2019  7.780   10.792   0.937      72.0    0.948      -0.052
# 119  Switzerland  2019  7.694   11.136   0.949      74.4    0.913       0.036
# 30       Denmark  2019  7.693   10.954   0.958      72.7    0.963       0.020
# 49       Iceland  2019  7.533   10.931   0.982      73.0    0.959       0.246
# 94        Norway  2019  7.442   11.061   0.942      73.3    0.954       0.111
#
#      corruption  mental  schooling  alcohol  suicide  birth  obesity  \
# 37        0.195   6.749       12.4    6.979    1.576  1.483    10.93
# 119       0.294   8.112       13.4    1.766    1.755  1.542     8.82
# 30        0.174   6.559       12.6    8.592    1.281  1.764     7.61
# 49        0.699   8.213       12.4    2.295    1.810  1.745    10.36
# 94        0.271   8.242       12.6    3.330    1.409  1.678     8.08
#
#     continent  kmeans
# 37         EU       1
# 119        EU       1
# 30         EU       1
# 49         EU       1
# 94         EU       1

# %%
df.sort_values(by='HS',ascending=False).tail()
# Out:
#          country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 138       Zambia  2019  3.307    8.155   0.638      55.8    0.811       0.077
# 105       Rwanda  2019  3.268    7.708   0.489      61.7    0.869       0.064
# 50         India  2019  3.249    8.818   0.561      60.5    0.876       0.112
# 139     Zimbabwe  2019  2.694    7.950   0.759      56.2    0.632      -0.064
# 0    Afghanistan  2019  2.375    7.697   0.420      52.4    0.394      -0.108
#
#      corruption  mental  schooling  alcohol  suicide  birth  obesity  \
# 138       0.832   2.835        7.0    2.797    0.981  4.559     2.82
# 105       0.168   3.903        4.1    2.811    1.139  3.990     2.87
# 50        0.752   4.660        6.4    2.319    2.128  2.202     5.37
# 139       0.831   2.543        8.2    0.920    2.250  3.531     4.86
# 0         0.924   3.240        3.8    0.683    0.761  4.321     8.50
#
#     continent  kmeans
# 138        AF       0
# 105        AF       0
# 50         AS       0
# 139        AF       0
# 0          AS       0

# %%
geo_temp=df

def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
geo_temp['CODE']=alpha3code(geo_temp['country'])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']
merge=pd.merge(world,geo_temp,on='CODE')

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['green','blue','red'])
ax = world.plot(figsize=(20,15), linewidth=0.25, edgecolor=background_color, color='lightgray')
ax.axis('off')
ax.set_facecolor(background_color)
merge.plot(column='kmeans',figsize=(20, 15),legend=False,cmap=cmap,ax=ax)


ax.text(-175,112,'Distribution of Happiness Score 2019',fontsize=30,fontweight='bold',color='#323232')
plt.show()
