# %%
import pandas as pd 
import geopandas as gpd 
import matplotlib.colors
import pycountry
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

background_color = "#fafafa"
#colors
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"

# %%
df= pd.read_csv('C:/py/2019.csv')
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
#        'birth', 'obesity', 'continent'],
#       dtype='object')

# %%
#kmeans
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=4)
kmeans.fit(df[['social']])
df['kmeans']= kmeans.labels_

# %%
df.sort_values(by='social',ascending=False).head()
# Out:
#           country  year     HS  log_gdp  social  life_exp  freedom  \
# 49        Iceland  2019  7.533   10.931   0.982      73.0    0.959
# 127  Turkmenistan  2019  5.474    9.651   0.982      62.6    0.892
# 6         Austria  2019  7.195   10.939   0.964      73.3    0.903
# 38         France  2019  6.690   10.740   0.958      74.0    0.827
# 30        Denmark  2019  7.693   10.954   0.958      72.7    0.963
#
#      generosity  corruption  mental  schooling  alcohol  suicide  birth  \
# 49        0.246    0.699000   8.213       12.4    2.295    1.810  1.745
# 127       0.285    0.741162   4.064        9.8    2.892    1.328  2.740
# 6         0.060    0.457000   6.882       12.1    3.308    1.747  1.544
# 38       -0.133    0.568000   8.412       11.5    3.701    1.911  1.846
# 30        0.020    0.174000   6.559       12.6    8.592    1.281  1.764
#
#      obesity continent  kmeans
# 49     10.36        EU       1
# 127    18.19        AS       1
# 6      11.24        EU       1
# 38      7.78        EU       1
# 30      7.61        EU       1

# %%
df.sort_values(by='social',ascending=False).tail()
# Out:
#          country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 124         Togo  2019  4.179    7.375   0.539      55.1    0.617       0.065
# 83       Morocco  2019  5.057    8.925   0.535      66.2    0.757      -0.244
# 105       Rwanda  2019  3.268    7.708   0.489      61.7    0.869       0.064
# 12         Benin  2019  4.976    8.098   0.442      54.7    0.770      -0.016
# 0    Afghanistan  2019  2.375    7.697   0.420      52.4    0.394      -0.108
#
#      corruption  mental  schooling  alcohol  suicide  birth  obesity  \
# 124       0.737   3.009        4.8    2.059    1.126  4.259     3.76
# 83        0.757   7.316        5.5    0.369    1.165  2.382    17.66
# 105       0.168   3.903        4.1    2.811    1.139  3.990     2.87
# 12        0.698   2.559        3.6    2.446    0.859  4.767     3.75
# 0         0.924   3.240        3.8    0.683    0.761  4.321     8.50
#
#     continent  kmeans
# 124        AF       0
# 83         AF       0
# 105        AF       0
# 12         AF       0
# 0          AS       0

# %%
geo_temp=df

def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
geo_temp['CODE']=alpha3code(geo_temp['country'])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']
merge=pd.merge(world,geo_temp,on='CODE')

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['red','blue','green'])
ax = world.plot(figsize=(20,15), linewidth=0.25, edgecolor=background_color, color='lightgray')
ax.axis('off')
ax.set_facecolor(background_color)
merge.plot(column='kmeans',figsize=(20, 15),legend=False,cmap=cmap,ax=ax)


ax.text(-175,112,'Distribution of social 2019',fontsize=30,fontweight='bold',color='#323232')
plt.show()
