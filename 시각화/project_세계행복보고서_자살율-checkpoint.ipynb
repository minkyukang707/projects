# %%
import pandas as pd 
import geopandas as gpd 
import matplotlib.colors
import pycountry
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

background_color = "#fafafa"
#colors
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"

# %%
df= pd.read_csv('C:/py/2019.csv')
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
#        'birth', 'obesity', 'continent'],
#       dtype='object')

# %%
#kmeans
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=4)
kmeans.fit(df[['suicide']])
df['kmeans']= kmeans.labels_

# %%
df.sort_values(by='suicide',ascending=False).head(10)
# Out:
#                   country  year     HS  log_gdp  social  life_exp  freedom  \
# 114           South Korea  2019  5.903   10.661   0.783      73.9    0.706
# 116             Sri Lanka  2019  4.213    9.479   0.815      67.4    0.824
# 60             Kazakhstan  2019  6.272   10.179   0.951      65.2    0.852
# 70              Lithuania  2019  6.064   10.518   0.918      67.9    0.780
# 110             Singapore  2019  6.378   11.486   0.925      77.1    0.938
# 81               Mongolia  2019  5.563    9.418   0.946      62.5    0.711
# 120                Taiwan  2019  6.537   10.871   0.893      69.6    0.814
# 104                Russia  2019  5.441   10.205   0.910      64.7    0.715
# 130  United Arab Emirates  2019  6.711   11.114   0.862      67.3    0.911
# 139              Zimbabwe  2019  2.694    7.950   0.759      56.2    0.632
#
#      generosity  corruption  mental  schooling  alcohol  suicide  birth  \
# 114      -0.055       0.718   7.492  12.100000    1.226    5.082  1.093
# 116       0.051       0.863   6.313  10.900000    2.047    3.587  2.188
# 60       -0.055       0.708   4.567  11.800000    8.693    3.167  2.733
# 70       -0.251       0.783   4.273  13.000000    9.239    2.525  1.684
# 110       0.027       0.070  10.208  11.500000    0.175    2.501  1.217
# 81        0.149       0.873   4.184  10.100000   13.870    2.473  2.867
# 120      -0.070       0.718   5.741   8.552078    1.467    2.424  1.174
# 104      -0.116       0.848   3.808  12.000000   14.416    2.393  1.830
# 130       0.129       0.355   8.050  10.800000    0.814    2.266  1.387
# 139      -0.064       0.831   2.543   8.200000    0.920    2.250  3.531
#
#      obesity continent  kmeans  CODE
# 114     5.30        AS       2  None
# 116     9.41        AS       2   LKA
# 60     16.55        AS       2   KAZ
# 70     14.63        EU       1   LTU
# 110     7.85        AS       1   SGP
# 81     13.04        AS       1   MNG
# 120     9.05        AS       1  None
# 104    15.61        EU       1  None
# 130    19.16        AS       1   ARE
# 139     4.86        AF       1   ZWE

# %%
df.sort_values(by='suicide',ascending=False).tail(10)
# Out:
#           country  year     HS  log_gdp  social  life_exp  freedom  \
# 109  Sierra Leone  2019  3.447    7.449   0.611      52.4    0.718
# 7      Azerbaijan  2019  5.173    9.575   0.887      65.8    0.854
# 125       Tunisia  2019  4.315    9.283   0.610      67.2    0.659
# 22           Chad  2019  4.251    7.365   0.640      48.7    0.537
# 57        Jamaica  2019  6.309    9.186   0.878      67.5    0.891
# 92        Nigeria  2019  4.356    8.544   0.734      50.1    0.729
# 51      Indonesia  2019  5.347    9.377   0.802      62.3    0.866
# 91          Niger  2019  5.004    7.106   0.677      54.0    0.831
# 44         Greece  2019  5.952   10.319   0.891      72.6    0.614
# 75           Mali  2019  4.988    7.752   0.755      52.2    0.670
#
#      generosity  corruption  mental  schooling  alcohol  suicide  birth  \
# 109       0.074       0.874   2.075        3.5    1.761    0.637  4.169
# 7        -0.214       0.457   4.111       10.7    3.459    0.571  2.063
# 125      -0.209       0.889   7.898        7.2    0.232    0.568  2.174
# 22        0.055       0.832   1.660        2.3    1.764    0.540  5.649
# 57       -0.137       0.885   5.744        9.8    0.529    0.534  1.965
# 92        0.032       0.873   2.256        6.2    2.035    0.508  5.317
# 51        0.555       0.861   4.517        8.0    0.314    0.482  2.288
# 91        0.026       0.729   1.872        2.0    1.457    0.437  6.824
# 44       -0.289       0.848   6.840       10.8    0.244    0.430  1.287
# 75       -0.038       0.670   1.610        2.3    1.275    0.390  5.785
#
#      obesity continent  kmeans CODE
# 109     3.03        AF       0  SLE
# 7      15.61        AS       0  AZE
# 125    15.65        AF       0  TUN
# 22      1.39        AF       0  TCD
# 57     15.10     Nor.A       0  JAM
# 92      1.63        AF       0  NGA
# 51      8.52        AS       0  IDN
# 91      1.48        AF       0  NER
# 44     10.29        EU       0  GRC
# 75      1.95        AF       0  MLI

# %%
geo_temp=df

def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
geo_temp['CODE']=alpha3code(geo_temp['country'])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']
merge=pd.merge(world,geo_temp,on='CODE')

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['red','blue','green'])
ax = world.plot(figsize=(20,15), linewidth=0.25, edgecolor=background_color, color='lightgray')
ax.axis('off')
ax.set_facecolor(background_color)
merge.plot(column='kmeans',figsize=(20, 15),legend=False,cmap=cmap,ax=ax)


ax.text(-175,112,'Distribution of suicide 2019',fontsize=30,fontweight='bold',color='#323232')
plt.show()
