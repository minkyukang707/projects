# %%
import pandas as pd 
import geopandas as gpd 
import matplotlib.colors
import pycountry
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

background_color = "#fafafa"
#colors
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"

# %%
df= pd.read_csv('C:/py/2019.csv')
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
#        'birth', 'obesity', 'continent'],
#       dtype='object')

# %%
#kmeans
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=4)
kmeans.fit(df[['life_exp']])
df['kmeans']= kmeans.labels_

# %%
df.sort_values(by='life_exp',ascending=False).head()
# Out:
#          country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 110    Singapore  2019  6.378   11.486   0.925      77.1    0.938       0.027
# 58         Japan  2019  5.908   10.632   0.878      75.1    0.806      -0.255
# 115        Spain  2019  6.457   10.618   0.949      74.7    0.778      -0.049
# 119  Switzerland  2019  7.694   11.136   0.949      74.4    0.913       0.036
# 38        France  2019  6.690   10.740   0.958      74.0    0.827      -0.133
#
#      corruption  mental  schooling  alcohol  suicide  birth  obesity  \
# 110       0.070  10.208       11.5    0.175    2.501  1.217     7.85
# 58        0.617   6.080       12.8    0.427    2.101  1.366     4.16
# 115       0.730   8.063        9.8    0.608    0.898  1.344     9.97
# 119       0.294   8.112       13.4    1.766    1.755  1.542     8.82
# 38        0.568   8.412       11.5    3.701    1.911  1.846     7.78
#
#     continent  kmeans
# 110        AS       1
# 58         AS       1
# 115        EU       1
# 119        EU       1
# 38         EU       1

# %%
df.sort_values(by='life_exp',ascending=False).tail()
# Out:
#            country  year     HS  log_gdp  social  life_exp  freedom  \
# 117       Eswatini  2019  4.396    9.070   0.759     51.27    0.597
# 92         Nigeria  2019  4.356    8.544   0.734     50.10    0.729
# 56   Cote d'Ivoire  2019  5.392    8.564   0.679     50.10    0.736
# 22            Chad  2019  4.251    7.365   0.640     48.70    0.537
# 67         Lesotho  2019  3.512    7.926   0.790     48.70    0.716
#
#      generosity  corruption  mental  schooling  alcohol  suicide  birth  \
# 117      -0.191       0.724   1.660        5.9    3.327    1.458  2.958
# 92        0.032       0.873   2.256        6.2    2.035    0.508  5.317
# 56       -0.017       0.799   2.444        5.2    2.498    1.036  4.593
# 22        0.055       0.832   1.660        2.3    1.764    0.540  5.649
# 67       -0.131       0.915   2.641        6.3    2.627    2.027  3.108
#
#      obesity continent  kmeans
# 117     6.90        AF       0
# 92      1.63        AF       0
# 56      3.89        AF       0
# 22      1.39        AF       0
# 67      7.07        AF       0

# %%
geo_temp=df

def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
geo_temp['CODE']=alpha3code(geo_temp['country'])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']
merge=pd.merge(world,geo_temp,on='CODE')

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['red','blue','green'])
ax = world.plot(figsize=(20,15), linewidth=0.25, edgecolor=background_color, color='lightgray')
ax.axis('off')
ax.set_facecolor(background_color)
merge.plot(column='kmeans',figsize=(20, 15),legend=False,cmap=cmap,ax=ax)


ax.text(-175,112,'Distribution of Life expectancy 2019',fontsize=30,fontweight='bold',color='#323232')
plt.show()
