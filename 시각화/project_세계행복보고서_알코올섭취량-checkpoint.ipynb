# %%
import pandas as pd 
import geopandas as gpd 
import matplotlib.colors
import pycountry
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

background_color = "#fafafa"
#colors
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"

# %%
df= pd.read_csv('C:/py/2019.csv')
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
#        'birth', 'obesity', 'continent'],
#       dtype='object')

# %%
#kmeans
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=4)
kmeans.fit(df[['alcohol']])
df['kmeans']= kmeans.labels_

# %%
df.sort_values(by='alcohol',ascending=False).head(10)
# Out:
#          country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 10       Belarus  2019  5.821    9.860   0.917      66.4    0.657      -0.186
# 34   El Salvador  2019  6.455    9.080   0.764      66.4    0.877      -0.109
# 104       Russia  2019  5.441   10.205   0.910      64.7    0.715      -0.116
# 129      Ukraine  2019  4.702    9.458   0.883      64.9    0.715      -0.081
# 81      Mongolia  2019  5.563    9.418   0.946      62.5    0.711       0.149
# 45     Guatemala  2019  6.262    9.064   0.774      65.1    0.901      -0.062
# 35       Estonia  2019  6.035   10.511   0.934      68.8    0.887      -0.096
# 65        Latvia  2019  5.970   10.336   0.936      67.1    0.698      -0.194
# 80       Moldova  2019  5.803    9.475   0.809      65.7    0.784      -0.092
# 70     Lithuania  2019  6.064   10.518   0.918      67.9    0.780      -0.251
#
#      corruption  mental  schooling  alcohol  suicide  birth  obesity  \
# 10        0.546   4.353       12.3   19.492    1.949  1.722    16.30
# 34        0.682   5.106        6.9   16.384    1.475  2.021    13.07
# 104       0.848   3.808       12.0   14.416    2.393  1.830    15.61
# 129       0.885   3.631       11.3   13.883    1.983  1.438    15.32
# 81        0.873   4.184       10.1   13.870    2.473  2.867    13.04
# 45        0.773   4.792        6.5   12.668    1.076  2.822     8.26
# 35        0.576   4.934       12.7   12.113    1.435  1.599    17.75
# 65        0.789   3.904       12.8   10.691    1.561  1.732    15.99
# 80        0.884   4.010       11.6    9.292    1.554  1.269    15.76
# 70        0.783   4.273       13.0    9.239    2.525  1.684    14.63
#
#     continent  kmeans
# 10         EU       1
# 34      Nor.A       1
# 104        EU       1
# 129        EU       1
# 81         AS       1
# 45      Nor.A       1
# 35         EU       1
# 65         EU       2
# 80         EU       2
# 70         EU       2

# %%
df.sort_values(by='alcohol',ascending=False).tail(10)
# Out:
#         country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 96    Palestine  2019  4.483    8.485   0.833     62.25    0.653      -0.163
# 59       Jordan  2019  4.453    9.201   0.793     67.00    0.726      -0.165
# 33        Egypt  2019  4.328    9.373   0.772     62.00    0.774      -0.199
# 44       Greece  2019  5.952   10.319   0.891     72.60    0.614      -0.289
# 126      Turkey  2019  4.872   10.246   0.792     67.20    0.631      -0.136
# 125     Tunisia  2019  4.315    9.283   0.610     67.20    0.659      -0.209
# 25     Colombia  2019  6.350    9.598   0.873     68.00    0.822      -0.172
# 62       Kuwait  2019  6.106   10.817   0.842     66.90    0.867      -0.104
# 9    Bangladesh  2019  5.114    8.467   0.673     64.80    0.902      -0.051
# 110   Singapore  2019  6.378   11.486   0.925     77.10    0.938       0.027
#
#      corruption  mental  schooling  alcohol  suicide  birth  obesity  \
# 96        0.829   8.847        9.1    0.308    1.004  3.560    15.38
# 59        0.739   8.634       10.4    0.266    1.106  2.691    19.14
# 33        0.818   5.629        7.2    0.247    0.952  3.280    20.52
# 44        0.848   6.840       10.8    0.244    0.430  1.287    10.29
# 126       0.760   7.440        8.0    0.243    0.710  2.055    16.27
# 125       0.889   7.898        7.2    0.232    0.568  2.174    15.65
# 25        0.854   5.871        8.3    0.225    1.244  1.789    10.67
# 62        0.560  11.531        7.3    0.207    1.680  2.077    21.45
# 9         0.656   5.710        5.8    0.185    1.053  2.011     4.36
# 110       0.070  10.208       11.5    0.175    2.501  1.217     7.85
#
#     continent  kmeans
# 96         AS       0
# 59         AS       0
# 33         AF       0
# 44         EU       0
# 126        AS       0
# 125        AF       0
# 25         SA       0
# 62         AS       0
# 9          AS       0
# 110        AS       0

# %%
geo_temp=df

def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
geo_temp['CODE']=alpha3code(geo_temp['country'])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']
merge=pd.merge(world,geo_temp,on='CODE')

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['red','blue','green'])
ax = world.plot(figsize=(20,15), linewidth=0.25, edgecolor=background_color, color='lightgray')
ax.axis('off')
ax.set_facecolor(background_color)
merge.plot(column='kmeans',figsize=(20, 15),legend=False,cmap=cmap,ax=ax)


ax.text(-175,112,'Distribution of alcohol 2019',fontsize=30,fontweight='bold',color='#323232')
plt.show()
