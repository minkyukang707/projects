# %%
import pandas as pd 
import geopandas as gpd 
import matplotlib.colors
import pycountry
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

background_color = "#fafafa"
#colors
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"

# %%
df= pd.read_csv('C:/py/2019.csv')
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
#        'birth', 'obesity', 'continent'],
#       dtype='object')

# %%
#kmeans
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=4)
kmeans.fit(df[['birth']])
df['kmeans']= kmeans.labels_

# %%
df.sort_values(by='birth',ascending=False).head(10)
# Out:
#           country  year     HS  log_gdp  social  life_exp  freedom  \
# 91          Niger  2019  5.004    7.106   0.677      54.0    0.831
# 75           Mali  2019  4.988    7.752   0.755      52.2    0.670
# 22           Chad  2019  4.251    7.365   0.640      48.7    0.537
# 92        Nigeria  2019  4.356    8.544   0.734      50.1    0.729
# 40         Gambia  2019  5.164    7.699   0.694      55.3    0.677
# 18   Burkina Faso  2019  4.741    7.691   0.683      54.4    0.678
# 122      Tanzania  2019  3.640    7.886   0.687      58.0    0.850
# 128        Uganda  2019  4.948    7.688   0.805      56.1    0.704
# 84     Mozambique  2019  4.932    7.155   0.742      55.2    0.870
# 12          Benin  2019  4.976    8.098   0.442      54.7    0.770
#
#      generosity  corruption  mental  schooling  alcohol  suicide  birth  \
# 91        0.026       0.729   1.872        2.0    1.457    0.437  6.824
# 75       -0.038       0.670   1.610        2.3    1.275    0.390  5.785
# 22        0.055       0.832   1.660        2.3    1.764    0.540  5.649
# 92        0.032       0.873   2.256        6.2    2.035    0.508  5.317
# 40        0.410       0.798   3.456        3.5    1.986    0.874  5.154
# 18       -0.004       0.729   2.022        1.5    2.684    0.826  5.109
# 122       0.100       0.589   3.123        5.8    2.345    0.770  4.832
# 128       0.139       0.826   3.352        6.1    2.215    0.872  4.824
# 84        0.073       0.682   2.338        3.5    3.900    1.060  4.783
# 12       -0.016       0.698   2.559        3.6    2.446    0.859  4.767
#
#      obesity continent  kmeans  CODE
# 91      1.48        AF       1   NER
# 75      1.95        AF       1   MLI
# 22      1.39        AF       1   TCD
# 92      1.63        AF       1   NGA
# 40      5.49        AF       1   GMB
# 18      2.57        AF       1   BFA
# 122     3.59        AF       1  None
# 128     2.07        AF       1   UGA
# 84      2.51        AF       1   MOZ
# 12      3.75        AF       1   BEN

# %%
df.sort_values(by='birth',ascending=False).tail(10)
# Out:
#                     country  year     HS  log_gdp  social  life_exp  freedom  \
# 115                   Spain  2019  6.457   10.618   0.949      74.7    0.778
# 29                   Cyprus  2019  6.137   10.585   0.776      73.9    0.740
# 55                    Italy  2019  6.445   10.655   0.838      73.8    0.709
# 102                Portugal  2019  6.095   10.457   0.876      72.6    0.882
# 44                   Greece  2019  5.952   10.319   0.891      72.6    0.614
# 80                  Moldova  2019  5.803    9.475   0.809      65.7    0.784
# 14   Bosnia and Herzegovina  2019  6.016    9.609   0.873      68.1    0.722
# 110               Singapore  2019  6.378   11.486   0.925      77.1    0.938
# 120                  Taiwan  2019  6.537   10.871   0.893      69.6    0.814
# 114             South Korea  2019  5.903   10.661   0.783      73.9    0.706
#
#      generosity  corruption  mental  schooling  alcohol  suicide  birth  \
# 115      -0.049       0.730   8.063   9.800000    0.608    0.898  1.344
# 29       -0.008       0.865   8.179  12.100000    0.530    0.911  1.321
# 55       -0.082       0.866   7.179  10.200000    0.389    0.697  1.313
# 102      -0.234       0.915   7.099   9.200000    1.637    1.194  1.303
# 44       -0.289       0.848   6.840  10.800000    0.244    0.430  1.287
# 80       -0.092       0.884   4.010  11.600000    9.292    1.554  1.269
# 14        0.079       0.963   4.197   9.700000    2.037    0.842  1.254
# 110       0.027       0.070  10.208  11.500000    0.175    2.501  1.217
# 120      -0.070       0.718   5.741   8.552078    1.467    2.424  1.174
# 114      -0.055       0.718   7.492  12.100000    1.226    5.082  1.093
#
#      obesity continent  kmeans  CODE
# 115     9.97        EU       0   ESP
# 29     10.75        AS       0   CYP
# 55     10.19        EU       0   ITA
# 102     9.47        EU       0   PRT
# 44     10.29        EU       0   GRC
# 80     15.76        EU       0  None
# 14     13.57        EU       0   BIH
# 110     7.85        AS       0   SGP
# 120     9.05        AS       0  None
# 114     5.30        AS       0  None

# %%
geo_temp=df

def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
geo_temp['CODE']=alpha3code(geo_temp['country'])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']
merge=pd.merge(world,geo_temp,on='CODE')

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['red','blue','green'])
ax = world.plot(figsize=(20,15), linewidth=0.25, edgecolor=background_color, color='lightgray')
ax.axis('off')
ax.set_facecolor(background_color)
merge.plot(column='kmeans',figsize=(20, 15),legend=False,cmap=cmap,ax=ax)


ax.text(-175,112,'Distribution of birth 2019',fontsize=30,fontweight='bold',color='#323232')
plt.show()
