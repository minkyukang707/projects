# %% [markdown]
# # Library & Data
# # 라이브러리 및 데이터 로드

# %% [markdown]
# # 세계행복지수 데이터 로드

# %%
import pandas as pd 
import numpy as np
file_path='C:/pyy/pjt/'

# %%
whr=pd.read_csv(file_path+'world-happiness-report.csv')
whr.shape
# Out:
# (1949, 11)

# %% [markdown]
# # 데이터 전처리1
# # 데이터병합

# %% [markdown]
# 추가할 데이터들과 통일성을 부여해야함
# 국가이름 통일
#
# <추가할데이터>
# 1. 정신잘환
# 2. 교육년수
# 3. 알콜섭취량
# 4. 자살률
# 5. 출생률
# 6. 비만률
#
# 각 데이터는 Code컬럼을 삭제하고 사용하려는 데이터값의 컬럼은 간소화시킨다
# 결측값은 전년도 값으로 채우기 위해 method='ffil'을 이용한다

# %%
#positive affectm negative affect 컬럼 제거
whr=whr.drop(['Positive affect','Negative affect'],axis=1)
whr=whr.rename(columns={'Country name':'Country','year':'Year'})

#나라이름 통일
whr.Country.replace('Czech Republic','Czechia',inplace=True)
whr.Country.replace('Hong Kong S.A.R. of China','Hong Kong',inplace=True)
whr.Country.replace('Taiwan Province of China','Taiwan',inplace=True)
whr.Country.replace('Palestinian Territories','Palestine',inplace=True)
whr.Country.replace("Ivory Coast","Cote d'Ivoire",inplace=True)
whr.Country.replace('Swaziland','Eswatini',inplace=True)
whr.shape
# Out:
# (1949, 9)

# %% [markdown]
# # 정신질환 데이터추가

# %%
#데이터로드
men=pd.read_csv(file_path+'mental-and-substance-use-as-share-of-disease.csv')
del men['Code']
men.rename\
    (columns={'Entity':'Country','DALYs (Disability-Adjusted Life Years) - Mental and substance use disorders - Sex: Both - Age: All Ages (Percent)':'Mental disorders'},inplace=True)
men.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           6468 non-null   object
#  1   Year              6468 non-null   int64
#  2   Mental disorders  6468 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 151.7+ KB

# %%
#세계행복지수데이터와 합치기
report1=pd.merge(whr,men,how='left',on=['Country','Year'])
#파일로 저장
report1.to_csv(file_path+'report1.csv',index=False) 
report1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1949 entries, 0 to 1948
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           1949 non-null   object
#  1   Year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Mental disorders                  1523 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 167.5+ KB

# %% [markdown]
# # 교육년수 데이터추가

# %%
scho=pd.read_csv(file_path+'mean-years-of-schooling-1.csv')
del scho['Code']
scho=\
    scho.rename(columns={'Entity':'Country','Average Total Years of Schooling for Adult Population (Lee-Lee (2016), Barro-Lee (2018) and UNDP (2018))':'schooling'})

# %%
#세계행복지수데이터와 합치기
report2=pd.merge(report1,scho,how='left',on=['Country','Year'])
#파일로 저장
report2.to_csv(file_path+'report2.csv',index=False) 
report2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           1949 non-null   object
#  1   Year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Mental disorders                  1523 non-null   float64
#  10  schooling                         1518 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %% [markdown]
# # 알콜섭취량 데이터추가

# %%
alc=pd.read_csv(file_path+'death-rates-from-alcohol-use-disorders (1).csv')
del alc['Code']
alc=\
    alc.rename(columns={'Entity':'Country','Deaths - Alcohol use disorders - Sex: Both - Age: Age-standardized (Rate)':'alcohol disorders'})

# %%
#세계행복지수데이터와 합치기
report3=pd.merge(report2,alc,how='left',on=['Country','Year'])
#파일로 저장
report3.to_csv(file_path+'report3.csv',index=False) 
report3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1949 entries, 0 to 1948
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           1949 non-null   object
#  1   Year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Mental disorders                  1523 non-null   float64
#  10  schooling                         1518 non-null   float64
# ...

# %% [markdown]
# # 자살률 데이터 추가

# %%
sui=pd.read_csv(file_path+'share-deaths-suicide.csv')
del sui['Code']
sui.rename\
    (columns={'Entity':'Country','Deaths - Self-harm - Sex: Both - Age: All Ages (Percent)':'suicide rates'},inplace=True)

# %%
#세계행복지수데이터와 합치기
report4=pd.merge(report3,sui,how='left',on=['Country','Year'])
#파일로 저장
report4.to_csv(file_path+'report4.csv',index=False) 
report4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1949 entries, 0 to 1948
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           1949 non-null   object
#  1   Year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Mental disorders                  1523 non-null   float64
#  10  schooling                         1518 non-null   float64
# ...

# %% [markdown]
# # 출산률 데이터추가

# %%
br=pd.read_csv(file_path+'children-per-woman-UN.csv')
del br['Code']
br.rename\
    (columns={'Entity':'Country','Estimates, 1950 - 2020: Annually interpolated demographic indicators - Total fertility (live births per woman)':'Fertility'},inplace=True)

# %%
#세계행복지수데이터와 합치기
report5=pd.merge(report4,br,how='left',on=['Country','Year'])
#파일로 저장
report5.to_csv(file_path+'report5.csv',index=False) 
report5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1949 entries, 0 to 1948
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           1949 non-null   object
#  1   Year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Mental disorders                  1523 non-null   float64
#  10  schooling                         1518 non-null   float64
# ...

# %% [markdown]
# # 비만율 데이터추가

# %%
obesity=pd.read_csv(file_path+'share-of-deaths-obesity.csv')
del obesity['Code']
obesity.rename(columns={'Entity':'Country','Obesity (IHME, 2019)':'Obesity'},inplace=True)

# %%
#세계행복지수데이터와 합치기
report6=pd.merge(report5,obesity,how='left',on=['Country','Year'])
report6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1949 entries, 0 to 1948
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           1949 non-null   object
#  1   Year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Mental disorders                  1523 non-null   float64
#  10  schooling                         1518 non-null   float64
# ...

# %%
#결측값을 method='ffill'로 채우기
report6.fillna(method='ffill',inplace=True)
#파일로 저장
report6.to_csv(file_path+'report6.csv',index=False)

# %% [markdown]
# # 병합데이터 로드

# %%
report6=pd.read_csv(file_path+'report6.csv',header=0)
report6.head()
# Out:
#        Country  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
# ...

# %%
report6.columns
# Out:
# Index(['Country', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Mental disorders', 'schooling',
#        'alcohol disorders', 'suicide rates', 'Fertility', 'Obesity'],
#       dtype='object')

# %%
#컬럼명을 간편하게 변경
report6.rename(columns={'Country':'country', 'Year':'year', 'Life Ladder':'HS', 'Log GDP per capita':'log_gdp',
       'Social support':'social', 'Healthy life expectancy at birth':'life_exp',
       'Freedom to make life choices':'freedom', 'Generosity':'generosity',
       'Perceptions of corruption':'corruption', 'Mental disorders':'mental',
       'alcohol disorders':'alcohol', 'suicide rates':'suicide', 'Fertility':'birth', 'Obesity':'obesity'},inplace=True)

# %%
report6.to_csv(file_path+'report7.csv',index=False)

# %%
df=pd.read_csv(file_path+'report7.csv',header=0)
df.head()
# Out:
#        country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 0  Afghanistan  2008  3.724    7.370   0.451     50.80    0.718       0.168
# 1  Afghanistan  2009  4.402    7.540   0.552     51.20    0.679       0.190
# 2  Afghanistan  2010  4.758    7.647   0.539     51.60    0.600       0.121
# 3  Afghanistan  2011  3.832    7.620   0.521     51.92    0.496       0.162
# 4  Afghanistan  2012  3.783    7.705   0.521     52.24    0.531       0.236
#
#    corruption    mental  schooling   alcohol   suicide  birth  obesity
# 0       0.882  2.298615        3.0  0.790189  0.589612  6.373     5.77
# 1       0.850  2.406117        3.1  0.770864  0.604684  6.180     6.23
# 2       0.707  2.539439        3.2  0.756928  0.626468  5.977     6.60
# 3       0.731  2.656310        3.3  0.740344  0.646059  5.770     6.87
# 4       0.776  2.745618        3.4  0.724151  0.658366  5.562     7.08

# %%
df.isna().sum()
# Out:
# country       0
# year          0
# HS            0
# log_gdp       0
# social        0
# life_exp      0
# freedom       0
# generosity    0
# corruption    0
# mental        0
# schooling     0
# alcohol       0
# suicide       0
# birth         0
# obesity       0
# dtype: int64

# %% [markdown]
# # 데이터 전처리 2
# # 결측값 처리 / 이상치 수정

# %%
import pandas as pd
import seaborn as sns
from statsmodels.formula.api import ols
import numpy as np
from scipy import stats
from scipy.stats import norm

# %%
df=pd.read_csv(file_path+'report7.csv',header=0)
df.shape
# Out:
# (1949, 15)

# %%
#소숫점 3째자리까지만 나타내기
df=round(df,3)

# %% [markdown]
# < 이상치 처리 >
# 1. 직접 데이터자료를 확인하여 오류직접 수정
# 2. 컬럼의 값이 3개이상 비는 경우(다른 나라의 값을 가져오는 경우) 그 국가는 삭제
# 3. 행의 갯수가 1개인 국가 삭제
# 4. 한개에서 두개에 컬럼이 비는 경우 그 컬럼의 평균으로 값을 채움

# %%
df[['HS', 'log_gdp', 'social', 'life_exp', 'freedom',
       'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
       'birth', 'obesity']].describe()
# Out:
#                 HS     log_gdp       social     life_exp      freedom  \
# count  1949.000000  1949.00000  1949.000000  1949.000000  1949.000000
# mean      5.466705     9.37386     0.813041    63.320679     0.742786
# std       1.115711     1.15281     0.118350     7.489910     0.142392
# min       2.375000     6.63500     0.290000    32.300000     0.258000
# 25%       4.640000     8.47400     0.750000    58.700000     0.646000
# 50%       5.386000     9.46100     0.836000    65.140000     0.765000
# 75%       6.283000    10.37000     0.905000    68.500000     0.856000
# max       8.019000    11.64800     0.987000    77.100000     0.985000
#
#         generosity   corruption       mental    schooling      alcohol  \
# count  1949.000000  1949.000000  1949.000000  1949.000000  1949.000000
# mean     -0.000406     0.741162     5.206613     8.552078     3.095871
# std       0.161456     0.188888     2.220480     3.173480     3.808963
# ...

# %%
import numpy as np
mean_cor=np.mean(df.corruption) #부패인식률의 평균 
mean_life=np.mean(df.life_exp) # 기대수명의 평균 
mean_sch=np.mean(df.schooling) # 교육년수의 평균 
mean_gen=np.mean(df.generosity) # 자비로움의 평균

# %%
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
#        'birth', 'obesity'],
#       dtype='object')

# %%
# 수정할 값 정리 
# 수정하는 나라와 수정된느 값 명시 

df.at[25,'social'] = 0.81 #algeira social 
df.at[66,'generosity'] = 0.347 # Australia genero
df.at[147,'generosity'] = 0.069 #Beligum genero
df.at[218,'generosity'] = -0.016 #brazil genero
df.at[263,'freedom'] = 0.819 # cambodia freedom 
df.at[342,'generosity'] = -0.176 #china genero 
df.at[342:343,'freedom'] = 0.853 #china freedom 
df.at[342:356,'corruption'] = mean_cor #china corrup

#congo data는 삭제 , 3개 이상의 컬럼값이 아예 존재하지 않음 
#행의 갯수가 1개인 컬럼들 삭제 

df.at[437,'generosity'] = -0.063 #Czechia genero 
df.at[449,'generosity'] = 0.24 #Denmark genero 
df.at[498,'generosity'] = -0.121 # egypt genero
df.at[498:499,'corruption'] = 0.914 # egypt corrupt

df.at[542,'corruption'] = 0.74 #ethiopia corrupt

df.at[564,'generosity'] = 0.126 #france genero 
df.at[606,'generosity'] = -0.221 # german genero 
df.at[636,'generosity'] = -.019 # greece genero 

#Hong Kong 삭제, 3개이상의 컬럼의 값이 존재하지 않음 

df.at[710,'generosity'] = -0.161 #Hungary genero
df.at[732,'generosity'] = -0.051 #India genero 
df.at[761,'generosity'] = 0.056 #Iran genero 
df.at[800,'generosity'] = 0.291 #israel genero 
df.at[815,'generosity'] = 0.113  #italy genero 
df.at[845,'generosity'] = -0.09 #japan genero 
df.at[860,'freedom'] = 0.646 #jordan freedom 
df.at[860,'generosity'] = -0.112 #jordan genero 

#kosovo 제거, 3개 이상의 컬럼의 값이 존재하지 않음 

df.at[986,'generosity'] = -0.099 #lesotho genero 
df.at[1027,'corruption'] = 0.773 #madagascar corrupt

df.at[1075:1080,'corruption'] = 0.67 #malta corrupt

df.at[1108,'generosity'] = -0.095 #mexico genero 
df.at[1197,'generosity'] = 0.317 #nepal genero 
df.at[1211,'generosity'] = 0.344 #netherlands genero 

#north cyprus 제거 

df.at[1422,'schooling'] = 8.4 #qatar schooling
df.at[1427,'generosity'] = -0.188 #romania genero 
df.at[1455,'generosity'] = 0.017 #rwanda genero 
df.at[1467,'generosity'] = 0.005 #saudi genero
df.at[1467,'freedom'] = 0.622 #saudi freedom

df.at[1521,'corruption'] = 0.064 #singapore corrupt

#somaliland region 삭제 

df.at[1559:1561,'generosity'] = mean_gen #somalia genero 
df.at[1559:1561,'schooling'] = mean_sch #somalia genero 

df.at[1566,'corruption'] = 0.859 #south africa corrupt

df.at[1597:1599,'generosity'] = mean_gen #south_sudan genero
df.at[1600,'generosity'] = -0.093 #spain genero

df.at[1669:1681,'schooling'] = mean_sch #taiwan schooling

df.at[1753,'generosity'] = -0.178 #turkey genero
df.at[1753,'corruption'] = 0.8 #turkey corrupt

df.at[1768,'freedom'] = 0.786 #Turkmenistan freedom
df.at[1769,'freedom'] = 0.786 #Turkmenistan freedom
df.at[1768:1777,'corruption'] = mean_cor #Turkmenistan corrupt
df.at[1768,'schooling'] = 9.9 #Turkmenistan schooling

df.at[1821,'generosity'] = 0.336 #United kingdom genero
df.at[1836,'generosity'] = 0.197 #united states genero
df.at[1894,'corruption'] = 0.754 #vietnam corrupt
df.at[1908,'corruption'] = 0.832 #yemen corrupt

# %%
# 국가별로 행의 갯수를 확인하여 1개인 국가들 확인
list1=pd.Series(df.country.value_counts())
list1.tail(10)
# Out:
# Eswatini    3
# Bhutan      3
# Gambia      3
# Somalia     3
# Belize      2
# Suriname    1
# Cuba        1
# Maldives    1
# Oman        1
# Guyana      1
# Name: country, dtype: int64

# %%
df.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Estonia', 'Ethiopia', 'Finland', 'France', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Guinea', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland',
# ...

# %%
#위에 적어놓은 나라들과 데이터갯수가 1개인 나라들 제거
df.set_index('country',inplace=True)

# %%
df=df.drop(index=['Cuba','Maldives','Oman','Guyana','Suriname','Hong Kong','North Cyprus','Kosovo','Somaliland region',
              'Congo (Brazzaville)', 'Congo (Kinshasa)'])

# %%
df.to_csv(file_path+'report8.csv')

# %%
df=pd.read_csv(file_path+'report8.csv')
df.head()
# Out:
#        country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 0  Afghanistan  2008  3.724    7.370   0.451     50.80    0.718       0.168
# 1  Afghanistan  2009  4.402    7.540   0.552     51.20    0.679       0.190
# 2  Afghanistan  2010  4.758    7.647   0.539     51.60    0.600       0.121
# 3  Afghanistan  2011  3.832    7.620   0.521     51.92    0.496       0.162
# 4  Afghanistan  2012  3.783    7.705   0.521     52.24    0.531       0.236
#
#    corruption  mental  schooling  alcohol  suicide  birth  obesity
# 0       0.882   2.299        3.0    0.790    0.590  6.373     5.77
# 1       0.850   2.406        3.1    0.771    0.605  6.180     6.23
# 2       0.707   2.539        3.2    0.757    0.626  5.977     6.60
# 3       0.731   2.656        3.3    0.740    0.646  5.770     6.87
# 4       0.776   2.746        3.4    0.724    0.658  5.562     7.08

# %% [markdown]
# # 대륙컬럼 추가
# # pycountry-convert 이용

# %%
# 나라이름으로 대륙(AF: 아프리카, AS: 아시아, EU: 유럽, NA: 북미, ... 등등)으로 바꾸기
# https://towardsdatascience.com/using-python-to-create-a-world-map-from-a-list-of-country-names-cd7480d03b10
# pip install pycountry-convert
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2
def get_continent(col):
    try:
        cn_a2_code =  country_name_to_country_alpha2(col)
    except:
        cn_a2_code = 'Unknown' 
    try:
        cn_continent = country_alpha2_to_continent_code(cn_a2_code)
    except:
        cn_continent = 'Unknown' 
    return (cn_continent)

df['continent'] = df.apply(lambda row: get_continent(row.country) , axis = 1)
df['continent']
# Out:
# 0       AS
# 1       AS
# 2       AS
# 3       AS
# 4       AS
#         ..
# 1885    AF
# 1886    AF
# 1887    AF
# 1888    AF
# 1889    AF
# Name: continent, Length: 1890, dtype: object

# %%
df.isna().sum()
# Out:
# country       0
# year          0
# HS            0
# log_gdp       0
# social        0
# life_exp      0
# freedom       0
# generosity    0
# corruption    0
# mental        0
# schooling     0
# alcohol       0
# suicide       0
# birth         0
# obesity       0
# continent     0
# dtype: int64

# %%
df.continent.unique()
# Out:
# ['AS', 'EU', 'AF', 'SA', 'OC', 'Nor.A']
# Categories (6, object): ['AS', 'EU', 'AF', 'SA', 'OC', 'Nor.A']

# %%
df.at[799:807,'continent']='AF'
df.loc[161:162,'continent']='NA'
df.loc[293:307,'continent']='NA'
df.loc[378:391,'continent']='NA'
df.loc[449:463,'continent']='NA'
df.loc[494:508,'continent']='NA'
df.loc[631:644,'continent']='NA'
df.loc[654:678,'continent']='NA'
df.loc[808:813,'continent']='NA'
df.loc[1062:1076,'continent']='NA'
df.loc[1193:1206,'continent']='NA'
df.loc[1285:1298,'continent']='NA'
df.loc[1677:1681,'continent']='NA'
df.loc[1777:1791,'continent']='NA'

# %%
#최종파일로 저장
df.to_csv(file_path+'final.csv',index=False)

# %%
#데이터 시각화를 위해 2019년도 데이터만 따로 저장
df[df.year==2019].to_csv(file_path+'2019.csv',index=False)

# %% [markdown]
# 대륙이름중 북아메리카를 뜻하는 NA는 시스템에서 NaN으로 인식하여 이후에 데이터 작업에서 제외된다. 때문에 모든 값을 바꿔야했다. final.csv파일을 모두 복사하여 한글파일에 붙여넣은다음 NA를 Nor.A로 수정했다. 이후에 final.csv파일에 그대로 복사하여 저장했다.

# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# 1. 대륙별 행복지수 수평막대그래프
# 2. 나라별 행복지수 수평막대그래프(상,하위 5개국)
# 3. 변수들간의 상관계수 히트맵
# 4. 각 변수별 행복지수(HS)와 상관계수 히트맵
# 5. HS, log_gdp, life_exp의 산점도
# 6. HS, corruption, birth 의 산점도

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
file_path='C:/pyy/pjt/'

# %%
df=pd.read_csv(file_path+'final.csv')

# %%
df['country']= df['country'].astype("category")
df['year']= df['year'].astype("category")
df['continent']= df['continent'].astype("category")
ndf=df.sample(frac=1,random_state=4).reset_index(drop=True)  # random_state 안 하면 DW가 실행시마다 달라짐
ndf.head()
# Out:
#       country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 0   Venezuela  2005  7.170    9.313   0.955     65.40    0.838       0.304
# 1       Spain  2018  6.513   10.605   0.910     74.40    0.722      -0.075
# 2  Kyrgyzstan  2014  5.252    8.460   0.898     62.78    0.736       0.355
# 3  Bangladesh  2013  4.660    8.116   0.530     61.96    0.742      -0.016
# 4       Ghana  2009  4.198    8.174   0.633     53.66    0.757       0.005
#
#    corruption  mental  schooling  alcohol  suicide  birth  obesity continent
# 0       0.720   5.565        7.4    0.846    1.780  2.629    12.11        SA
# 1       0.777   8.063        9.8    0.608    0.898  1.333     9.97        EU
# 2       0.897   4.409       10.8    7.380    1.811  3.241    10.95        AS
# 3       0.743   5.204        5.1    0.182    1.129  2.188     4.08        AS
# 4       0.890   2.503        6.7    2.131    0.731  4.311     4.89        AF

# %%
# HS 정규화 안 함 -> ndfnor

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
x= ndf[['log_gdp', 'social', 'life_exp', 'freedom','generosity', 'corruption', 
       'schooling', 'alcohol', 'suicide','obesity', 'birth', 'mental']]
xnor = MinMaxScaler().fit_transform(x)

ndfnor = pd.DataFrame(xnor)
ndfnor.columns = ['log_gdp', 'social', 'life_exp', 'freedom', 'generosity', 'corruption', 'schooling', 'alcohol',
                     'suicide','obesity', 'birth', 'mental']

# 정규화 안한 컬럼 dfnor에 추가
ndfnor[['HS','year','country','continent']]= ndf[['HS','year','country','continent']]
ndfnor.head()
# Out:
#     log_gdp    social  life_exp   freedom  generosity  corruption  schooling  \
# 0  0.534211  0.954089  0.738839  0.797799    0.618587    0.722574   0.476562
# 1  0.791941  0.889527  0.939732  0.638239    0.251694    0.782700   0.664062
# 2  0.364053  0.872310  0.680357  0.657497    0.667957    0.909283   0.742188
# 3  0.295432  0.344333  0.662054  0.665750    0.308809    0.746835   0.296875
# 4  0.307002  0.492109  0.476786  0.686382    0.329138    0.901899   0.421875
#
#     alcohol   suicide   obesity     birth    mental     HS  year     country  \
# 0  0.025457  0.242320  0.451977  0.240899  0.426285  7.170  2005   Venezuela
# 1  0.016428  0.104075  0.365617  0.042674  0.649620  6.513  2018       Spain
# 2  0.273352  0.247179  0.405165  0.334506  0.322932  5.252  2014  Kyrgyzstan
# 3  0.000266  0.140282  0.127926  0.173448  0.394010  4.660  2013  Bangladesh
# 4  0.074209  0.077900  0.160613  0.498165  0.152526  4.198  2009       Ghana
#
#   continent
# 0        SA
# 1        EU
# ...

# %%
# HS도 정규화 -> ndfnor2

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
x2= ndf[['log_gdp', 'social', 'life_exp', 'freedom','generosity', 'corruption', 
       'schooling', 'alcohol', 'suicide','obesity', 'birth', 'mental','HS']]
xnor2 = MinMaxScaler().fit_transform(x2)

ndfnor2 = pd.DataFrame(xnor2)
ndfnor2.columns = ['log_gdp', 'social', 'life_exp', 'freedom', 'generosity', 'corruption', 'schooling', 'alcohol',
                     'suicide','obesity', 'birth', 'mental','HS']

ndfnor2[['year','country','continent']]= ndf[['year','country','continent']]
ndfnor2.head()
# Out:
#     log_gdp    social  life_exp   freedom  generosity  corruption  schooling  \
# 0  0.534211  0.954089  0.738839  0.797799    0.618587    0.722574   0.476562
# 1  0.791941  0.889527  0.939732  0.638239    0.251694    0.782700   0.664062
# 2  0.364053  0.872310  0.680357  0.657497    0.667957    0.909283   0.742188
# 3  0.295432  0.344333  0.662054  0.665750    0.308809    0.746835   0.296875
# 4  0.307002  0.492109  0.476786  0.686382    0.329138    0.901899   0.421875
#
#     alcohol   suicide   obesity     birth    mental        HS  year  \
# 0  0.025457  0.242320  0.451977  0.240899  0.426285  0.849575  2005
# 1  0.016428  0.104075  0.365617  0.042674  0.649620  0.733168  2018
# 2  0.273352  0.247179  0.405165  0.334506  0.322932  0.509745  2014
# 3  0.000266  0.140282  0.127926  0.173448  0.394010  0.404855  2013
# 4  0.074209  0.077900  0.160613  0.498165  0.152526  0.322998  2009
#
#       country continent
# 0   Venezuela        SA
# 1       Spain        EU
# ...

# %% [markdown]
# # 군집분류

# %%
from sklearn import cluster
X = ndfnor[['HS']]
kmeans = cluster.KMeans(init='k-means++', n_clusters = 3, n_init = 10,random_state=4)
kmeans.fit(X)                 
cluster_label = kmeans.labels_

# %%
ndfnor['cluster'] = cluster_label
ndfnor.head()
# Out:
#     log_gdp    social  life_exp   freedom  generosity  corruption  schooling  \
# 0  0.534211  0.954089  0.738839  0.797799    0.618587    0.722574   0.476562
# 1  0.791941  0.889527  0.939732  0.638239    0.251694    0.782700   0.664062
# 2  0.364053  0.872310  0.680357  0.657497    0.667957    0.909283   0.742188
# 3  0.295432  0.344333  0.662054  0.665750    0.308809    0.746835   0.296875
# 4  0.307002  0.492109  0.476786  0.686382    0.329138    0.901899   0.421875
#
#     alcohol   suicide   obesity     birth    mental     HS  year     country  \
# 0  0.025457  0.242320  0.451977  0.240899  0.426285  7.170  2005   Venezuela
# 1  0.016428  0.104075  0.365617  0.042674  0.649620  6.513  2018       Spain
# 2  0.273352  0.247179  0.405165  0.334506  0.322932  5.252  2014  Kyrgyzstan
# 3  0.000266  0.140282  0.127926  0.173448  0.394010  4.660  2013  Bangladesh
# 4  0.074209  0.077900  0.160613  0.498165  0.152526  4.198  2009       Ghana
#
#   continent  cluster
# ...

# %%
ndfnor2['cluster'] = cluster_label
ndfnor2.head()
# Out:
#     log_gdp    social  life_exp   freedom  generosity  corruption  schooling  \
# 0  0.534211  0.954089  0.738839  0.797799    0.618587    0.722574   0.476562
# 1  0.791941  0.889527  0.939732  0.638239    0.251694    0.782700   0.664062
# 2  0.364053  0.872310  0.680357  0.657497    0.667957    0.909283   0.742188
# 3  0.295432  0.344333  0.662054  0.665750    0.308809    0.746835   0.296875
# 4  0.307002  0.492109  0.476786  0.686382    0.329138    0.901899   0.421875
#
#     alcohol   suicide   obesity     birth    mental        HS  year  \
# 0  0.025457  0.242320  0.451977  0.240899  0.426285  0.849575  2005
# 1  0.016428  0.104075  0.365617  0.042674  0.649620  0.733168  2018
# 2  0.273352  0.247179  0.405165  0.334506  0.322932  0.509745  2014
# 3  0.000266  0.140282  0.127926  0.173448  0.394010  0.404855  2013
# 4  0.074209  0.077900  0.160613  0.498165  0.152526  0.322998  2009
#
#       country continent  cluster
# 0   Venezuela        SA        2
# ...

# %%
ndfnor.replace({'cluster': 1}, {'cluster': 'Mid'},inplace=True)
ndfnor.replace({'cluster': 0}, {'cluster': 'Low'},inplace=True)
ndfnor.replace({'cluster': 2}, {'cluster': 'High'},inplace=True)
ndfnor.head()
# Out:
#     log_gdp    social  life_exp   freedom  generosity  corruption  schooling  \
# 0  0.534211  0.954089  0.738839  0.797799    0.618587    0.722574   0.476562
# 1  0.791941  0.889527  0.939732  0.638239    0.251694    0.782700   0.664062
# 2  0.364053  0.872310  0.680357  0.657497    0.667957    0.909283   0.742188
# 3  0.295432  0.344333  0.662054  0.665750    0.308809    0.746835   0.296875
# 4  0.307002  0.492109  0.476786  0.686382    0.329138    0.901899   0.421875
#
#     alcohol   suicide   obesity     birth    mental     HS  year     country  \
# 0  0.025457  0.242320  0.451977  0.240899  0.426285  7.170  2005   Venezuela
# 1  0.016428  0.104075  0.365617  0.042674  0.649620  6.513  2018       Spain
# 2  0.273352  0.247179  0.405165  0.334506  0.322932  5.252  2014  Kyrgyzstan
# 3  0.000266  0.140282  0.127926  0.173448  0.394010  4.660  2013  Bangladesh
# 4  0.074209  0.077900  0.160613  0.498165  0.152526  4.198  2009       Ghana
#
#   continent cluster
# ...

# %%
ndfnor2.replace({'cluster': 1}, {'cluster': 'Mid'},inplace=True)
ndfnor2.replace({'cluster': 0}, {'cluster': 'Low'},inplace=True)
ndfnor2.replace({'cluster': 2}, {'cluster': 'High'},inplace=True)
ndfnor2.head()
# Out:
#     log_gdp    social  life_exp   freedom  generosity  corruption  schooling  \
# 0  0.534211  0.954089  0.738839  0.797799    0.618587    0.722574   0.476562
# 1  0.791941  0.889527  0.939732  0.638239    0.251694    0.782700   0.664062
# 2  0.364053  0.872310  0.680357  0.657497    0.667957    0.909283   0.742188
# 3  0.295432  0.344333  0.662054  0.665750    0.308809    0.746835   0.296875
# 4  0.307002  0.492109  0.476786  0.686382    0.329138    0.901899   0.421875
#
#     alcohol   suicide   obesity     birth    mental        HS  year  \
# 0  0.025457  0.242320  0.451977  0.240899  0.426285  0.849575  2005
# 1  0.016428  0.104075  0.365617  0.042674  0.649620  0.733168  2018
# 2  0.273352  0.247179  0.405165  0.334506  0.322932  0.509745  2014
# 3  0.000266  0.140282  0.127926  0.173448  0.394010  0.404855  2013
# 4  0.074209  0.077900  0.160613  0.498165  0.152526  0.322998  2009
#
#       country continent cluster
# 0   Venezuela        SA    High
# ...

# %% [markdown]
# 1. 대륙별 행복지수 수평막대그래프

# %%
# 대륙별 행복지수 구하기 
HS_mean = ndfnor.groupby(['continent'])['HS'].mean().to_frame().sort_values(by='HS',ascending = False)
HS_mean = HS_mean.reset_index()

# %%
from matplotlib import font_manager, rc
import seaborn as sns
plt.style.use('default')
plt.rc('font', family='Malgun Gothic')
plt.title('Happiness Score of Each Continent', y = 1.02)
palette = sns.set_palette("GnBu")
sns.barplot('HS','continent', data=HS_mean)
# Out:
# C:\Users\K\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Happiness Score of Each Continent'}, xlabel='HS', ylabel='continent'>

# %% [markdown]
# 2. 나라별 행복지수 수평막대그래프(상,하위 5개국)

# %%
# 나라별 행복지수 구하기
ndfnor['country']= ndfnor['country'].astype("object")
HS_mean_country = ndfnor.groupby(['country'])['HS'].mean().to_frame().sort_values(by='HS',ascending = False)
HS_mean_country
# Out:
#                                 HS
# country
# Denmark                   7.680400
# Finland                   7.597154
# Switzerland               7.548300
# Norway                    7.512400
# Netherlands               7.466286
# ...                            ...
# Afghanistan               3.594667
# Togo                      3.555000
# Burundi                   3.548200
# Central African Republic  3.515000
# South Sudan               3.402000
#
# [155 rows x 1 columns]

# %%
# 상위 5개 국가, 하위 5개 국가
HS_mean_country_top = HS_mean_country.head(5)
HS_mean_country_bot = HS_mean_country.tail(5)
HS_mean_country = pd.concat([HS_mean_country_top,HS_mean_country_bot])
HS_mean_country.index
# Out:
# Index(['Denmark', 'Finland', 'Switzerland', 'Norway', 'Netherlands',
#        'Afghanistan', 'Togo', 'Burundi', 'Central African Republic',
#        'South Sudan'],
#       dtype='object', name='country')

# %%
# 나라별 행복지수 막대그래프
plt.title('The Happiest & Unhappiest Countries in the World', y = 1.02)
sns.barplot(data=HS_mean_country,x='HS', y=HS_mean_country.index, palette = 'YlGnBu')
plt.show()

# %% [markdown]
# 3. 변수들간의 상관계수 히트맵

# %%
data = ndfnor.drop(['cluster','continent','country','year'],axis=1)
np.triu(np.ones_like(data.corr()))
mask = np.triu(np.ones_like(data.corr(), dtype=np.bool))
plt.rcParams['axes.unicode_minus']=False 
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), 
            mask=mask, 
            vmin=-1, 
            vmax = 1, 
            annot=True, 
            cmap="PuBu", 
            cbar = True)
plt.title('Correlation Heatmap', pad = 12)
plt.show()

# %% [markdown]
# 4. 각 변수별 행복지수(HS)와 상관계수 히트맵

# %%
print(data.corr()[['HS']].sort_values(by='HS', ascending=False))
data_ylabels = data.corr()[['HS']].sort_values(by='HS', ascending=False).index.tolist()
data.corr()[['HS']].sort_values(by='HS', ascending=False).index
fig, ax = plt.subplots(figsize=(5, 10))
sns.heatmap(data.corr()[['HS']].sort_values(by='HS', ascending=False), 
            vmin = -1, vmax = 1, annot=True, cmap="BrBG")
ax.set_title('Correlation Heatmap with Happiness Score', pad = 12)
ax.set_yticklabels(data_ylabels, rotation=0) # y축을 가로형으로 변환
plt.show()


# log_gdp, life_exp가 양의 상관관계, corruption, birth가 음의 상관관계
# Out:
#                   HS
# HS          1.000000
# log_gdp     0.785857
# life_exp    0.743997
# social      0.709413
# mental      0.682258
# schooling   0.653265
# freedom     0.524971
# obesity     0.361052
# suicide     0.345651
# generosity  0.195041
# alcohol     0.104212
# corruption -0.453061
# birth      -0.599130

# %% [markdown]
# 5. HS, log_gdp, life_exp의 산점도
# - log_gdp가 높을수록, life_exp가 높을수록 행복지수도 높아짐.

# %%
# HS, log_gdp, life_exp의 산점도 
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [15, 10]
sns.scatterplot(data=ndfnor2,   # 버블의 크기변화가 정규화된 HS에서 더 잘 나타나서 행복지수 정규화값으로 반영
                x="log_gdp", 
                y="life_exp", 
                size="HS", 
                hue='cluster',
                alpha = 0.8, 
                palette="GnBu",
                legend=True, 
                sizes=(20, 800))
plt.title('Happiness Score, GDP, and Life Expectancy', y = 1.02)
# Out:
# Text(0.5, 1.02, 'Happiness Score, GDP, and Life Expectancy')

# %% [markdown]
# 6. HS, corruption, birth 의 산점도
# - 행복지수가 낮은 나라일수록 birth와 corruption이 높은 것을 알 수 있음
# - 행복지수가 높은 나라에서는 corruption 수치는 어느정도 고르게 분포하지만 birth가 확실히 낮음

# %%
# HS, corruption, birth 의 산점도 
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [15, 10]
sns.scatterplot(data=ndfnor2,  # 버블의 크기변화가 정규화된 HS에서 더 잘 나타남 
                x="corruption", 
                y="birth", 
                size="HS", 
                hue='cluster',
                alpha = 0.8, 
                palette="GnBu",
                legend=True, 
                sizes=(20, 800))
plt.title('Happiness Score, Corruption, and Birth Rate', y = 1.02)
# Out:
# Text(0.5, 1.02, 'Happiness Score, Corruption, and Birth Rate')
