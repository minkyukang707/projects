# %%
import pandas as pd 
import geopandas as gpd 
import matplotlib.colors
import pycountry
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

background_color = "#fafafa"
#colors
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"

# %%
df= pd.read_csv('C:/py/2019.csv')
df.columns
# Out:
# Index(['country', 'year', 'HS', 'log_gdp', 'social', 'life_exp', 'freedom',
#        'generosity', 'corruption', 'mental', 'schooling', 'alcohol', 'suicide',
#        'birth', 'obesity', 'continent'],
#       dtype='object')

# %%
#kmeans
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, random_state=4)
kmeans.fit(df[['log_gdp']])
df['kmeans']= kmeans.labels_

# %%
df.sort_values(by='log_gdp',ascending=False).head()
# Out:
#                   country  year     HS  log_gdp  social  life_exp  freedom  \
# 71             Luxembourg  2019  7.404   11.648   0.912      72.6    0.930
# 110             Singapore  2019  6.378   11.486   0.925      77.1    0.938
# 53                Ireland  2019  7.255   11.371   0.944      72.4    0.892
# 119           Switzerland  2019  7.694   11.136   0.949      74.4    0.913
# 130  United Arab Emirates  2019  6.711   11.114   0.862      67.3    0.911
#
#      generosity  corruption  mental  schooling  alcohol  suicide  birth  \
# 71       -0.045       0.390   7.760       12.1    3.039    1.560  1.432
# 110       0.027       0.070  10.208       11.5    0.175    2.501  1.217
# 53        0.074       0.373   8.932       12.5    1.602    1.470  1.821
# 119       0.036       0.294   8.112       13.4    1.766    1.755  1.542
# 130       0.129       0.355   8.050       10.8    0.814    2.266  1.387
#
#      obesity continent  kmeans
# 71      9.85        EU       1
# 110     7.85        AS       1
# 53      9.11        EU       1
# 119     8.82        EU       1
# 130    19.16        AS       1

# %%
df.sort_values(by='log_gdp',ascending=False).tail()
# Out:
#        country  year     HS  log_gdp  social  life_exp  freedom  generosity  \
# 22        Chad  2019  4.251    7.365   0.640      48.7    0.537       0.055
# 68     Liberia  2019  5.121    7.264   0.712      56.9    0.706       0.051
# 84  Mozambique  2019  4.932    7.155   0.742      55.2    0.870       0.073
# 91       Niger  2019  5.004    7.106   0.677      54.0    0.831       0.026
# 73      Malawi  2019  3.869    6.966   0.549      58.3    0.765       0.004
#
#     corruption  mental  schooling  alcohol  suicide  birth  obesity continent  \
# 22       0.832   1.660        2.3    1.764    0.540  5.649     1.39        AF
# 68       0.828   2.847        4.7    2.030    1.089  4.247     4.58        AF
# 84       0.682   2.338        3.5    3.900    1.060  4.783     2.51        AF
# 91       0.729   1.872        2.0    1.457    0.437  6.824     1.48        AF
# 73       0.680   2.646        4.5    2.714    0.918  4.127     2.79        AF
#
#     kmeans
# 22       0
# 68       0
# 84       0
# 91       0
# 73       0

# %%
geo_temp=df

def alpha3code(column):
    CODE=[]
    for country in column:
        try:
            code=pycountry.countries.get(name=country).alpha_3
            CODE.append(code)
        except:
            CODE.append('None')
    return CODE
# create a column for code 
geo_temp['CODE']=alpha3code(geo_temp['country'])

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.columns=['pop_est', 'continent', 'name', 'CODE', 'gdp_md_est', 'geometry']
merge=pd.merge(world,geo_temp,on='CODE')

# %%
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['red','blue','green'])
ax = world.plot(figsize=(20,15), linewidth=0.25, edgecolor=background_color, color='lightgray')
ax.axis('off')
ax.set_facecolor(background_color)
merge.plot(column='kmeans',figsize=(20, 15),legend=False,cmap=cmap,ax=ax)


ax.text(-175,112,'Distribution of GDP 2019',fontsize=30,fontweight='bold',color='#323232')
plt.show()
